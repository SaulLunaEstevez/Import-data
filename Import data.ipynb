# %%
import numpy as np
import urllib.request
txt = urllib.request.urlopen('https://www.gutenberg.org/files/60261/60261-0.txt')
print(txt.read())
# Out:
# b'\xef\xbb\xbfProject Gutenberg\'s The Five Nations, Volume II (of 2), by Rudyard Kipling\r\n\r\nThis eBook is for the use of anyone anywhere in the United States and most\r\nother parts of the world at no cost and with almost no restrictions\r\nwhatsoever.  You may copy it, give it away or re-use it under the terms of\r\nthe Project Gutenberg License included with this eBook or online at\r\nwww.gutenberg.org.  If you are not located in the United States, you\'ll have\r\nto check the laws of the country where you are located before using this ebook.\r\n\r\nTitle: The Five Nations, Volume II (of 2)\r\n\r\nAuthor: Rudyard Kipling\r\n\r\nRelease Date: September 8, 2019 [EBook #60261]\r\n\r\nLanguage: English\r\n\r\nCharacter set encoding: UTF-8\r\n\r\n*** START OF THIS PROJECT GUTENBERG EBOOK THE FIVE NATIONS, VOLUME II (OF 2) ***\r\n\r\n\r\n\r\n\r\nProduced by deaurider, Charlie Howard, and the Online\r\nDistributed Proofreading Team at http://www.pgdp.net (This\r\nfile was produced fr
# ...

# %%
data= pd.read_csv('http://insight.dev.schoolwires.com/HelpAssets/C2Assets/C2Files/C2ImportCalEventSample.csv')

# %%
data
# Out:
#   Start Date   Start Time  End Date    End Time                  Event Title   \
# 0    9/5/2011  3:00:00 PM  9/5/2011         NaN  Social Studies Dept. Meeting
# 1    9/5/2011  6:00:00 PM  9/5/2011  8:00:00 PM            Curriculum Meeting
#
#   All Day Event No End Time   Event Description         Contact   \
# 0             N           Y  Department meeting  Chris Gallagher
# 1             N           N  Curriculum Meeting  Chris Gallagher
#
#                 Contact Email Contact Phone     Location  Category Mandatory  \
# 0  cgallagher@schoolwires.com  814-555-5179  High School         2         N
# 1  cgallagher@schoolwires.com  814-555-5179  High School         2         N
#
#   Registration  Maximum Last Date To Register
# 0            N       25              9/2/2011
# 1            N       25              9/2/2011

# %%
import json
import urllib3
http=urllib3.PoolManager()
url= 'https://support.oneskyapp.com/hc/en-us/article_attachments/202761727/example_2.json'
url2= http.request('GET',url)
jason= json.loads(url2.data)
print(jason)
# Out:
# {'quiz': {'sport': {'q1': {'question': 'Which one is correct team name in NBA?', 'options': ['New York Bulls', 'Los Angeles Kings', 'Golden State Warriros', 'Huston Rocket'], 'answer': 'Huston Rocket'}}, 'maths': {'q1': {'question': '5 + 7 = ?', 'options': ['10', '11', '12', '13'], 'answer': '12'}, 'q2': {'question': '12 - 8 = ?', 'options': ['1', '2', '3', '4'], 'answer': '4'}}}}

# %%
e=pd.read_excel('https://file-examples.com/wp-content/uploads/2017/02/file_example_XLSX_50.xlsx')
e
# Out:
#      0 First Name   Last Name  Gender        Country  Age        Date    Id
# 0    1      Dulce       Abril  Female  United States   32  15/10/2017  1562
# 1    2       Mara   Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2    3     Philip        Gent    Male         France   36  21/05/2015  2587
# 3    4   Kathleen      Hanner  Female  United States   25  15/10/2017  3549
# 4    5    Nereida     Magwood  Female  United States   58  16/08/2016  2468
# 5    6     Gaston       Brumm    Male  United States   24  21/05/2015  2554
# 6    7       Etta        Hurn  Female  Great Britain   56  15/10/2017  3598
# 7    8    Earlean      Melgar  Female  United States   27  16/08/2016  2456
# 8    9   Vincenza     Weiland  Female  United States   40  21/05/2015  6548
# 9   10     Fallon     Winward  Female  Great Britain   28  16/08/2016  5486
# 10  11    Arcelia      Bouska  Female  Great Britain   39  21/05/2015  1258
# ...

# %%
from urllib.request import urlopen
from xml.etree.ElementTree import parse

var_url = urlopen('https://www.w3schools.com/xml/note.xml')
xmldoc = parse(var_url)

for item in xmldoc.iterfind('channel/item'):
    title = item.findtext('title')
    date = item.findtext('pubDate')
    link = item.findtext('link')

    print(title)
    print(date)
    print(link)
    print()
